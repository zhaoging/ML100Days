# %% [markdown]
# 範例目標:<br>
# 1. 讀寫csv
# 2. 讀寫excel
# 3. 讀寫json
# 4. 讀寫SQL資料庫

# %% [markdown]
# 範例重點:<br>
# 1. 讀寫不同檔案格式會有不同程式可以達到csv(read_csv、to_csv)、excel(read_excel、to_excel)、json(read_json、to_json)、SQL資料庫(io.sql.read_sql、to_sql)
# 2. 讀取進來後都是DataFrame的型態

# %%
import pandas as pd

# %%
# !pip install openpyxl
# !pip install XLRD
# Out:
# Requirement already satisfied: openpyxl in /home/zhaoging/.local/lib/python3.8/site-packages (3.0.6)
# Requirement already satisfied: jdcal in /home/zhaoging/.local/lib/python3.8/site-packages (from openpyxl) (1.4.1)
# Requirement already satisfied: et-xmlfile in /home/zhaoging/.local/lib/python3.8/site-packages (from openpyxl) (1.0.1)
# Requirement already satisfied: XLRD in /home/zhaoging/.local/lib/python3.8/site-packages (2.0.1)

# %%
iris_data = pd.read_csv('iris.csv')
iris_data
# Out:
#      sepal length  sepal width  petal length  petal width  target
# 0             5.1          3.5           1.4          0.2       0
# 1             4.9          3.0           1.4          0.2       0
# 2             4.7          3.2           1.3          0.2       0
# 3             4.6          3.1           1.5          0.2       0
# 4             5.0          3.6           1.4          0.2       0
# ..            ...          ...           ...          ...     ...
# 145           6.7          3.0           5.2          2.3       2
# 146           6.3          2.5           5.0          1.9       2
# 147           6.5          3.0           5.2          2.0       2
# 148           6.2          3.4           5.4          2.3       2
# 149           5.9          3.0           5.1          1.8       2
#
# [150 rows x 5 columns]

# %%
iris_data = pd.read_csv('iris.csv',usecols=['petal length','petal width','target'])
iris_data
# Out:
#      petal length  petal width  target
# 0             1.4          0.2       0
# 1             1.4          0.2       0
# 2             1.3          0.2       0
# 3             1.5          0.2       0
# 4             1.4          0.2       0
# ..            ...          ...     ...
# 145           5.2          2.3       2
# 146           5.0          1.9       2
# 147           5.2          2.0       2
# 148           5.4          2.3       2
# 149           5.1          1.8       2
#
# [150 rows x 3 columns]

# %%
iris_data = pd.read_csv('iris.csv',header=0,names=['featrue1','featrue2','featrue3','featrue4','target'])
iris_data
# Out:
#      featrue1  featrue2  featrue3  featrue4  target
# 0         5.1       3.5       1.4       0.2       0
# 1         4.9       3.0       1.4       0.2       0
# 2         4.7       3.2       1.3       0.2       0
# 3         4.6       3.1       1.5       0.2       0
# 4         5.0       3.6       1.4       0.2       0
# ..        ...       ...       ...       ...     ...
# 145       6.7       3.0       5.2       2.3       2
# 146       6.3       2.5       5.0       1.9       2
# 147       6.5       3.0       5.2       2.0       2
# 148       6.2       3.4       5.4       2.3       2
# 149       5.9       3.0       5.1       1.8       2
#
# [150 rows x 5 columns]

# %%
iris_data.to_csv('my_iris.csv')

# %%
data = pd.read_excel('data.xls')
data
# Out:
#      sepal length  sepal width  petal length  petal width  target
# 0             5.1          3.5           1.4          0.2       0
# 1             4.9          3.0           1.4          0.2       0
# 2             4.7          3.2           1.3          0.2       0
# 3             4.6          3.1           1.5          0.2       0
# 4             5.0          3.6           1.4          0.2       0
# ..            ...          ...           ...          ...     ...
# 145           6.7          3.0           5.2          2.3       2
# 146           6.3          2.5           5.0          1.9       2
# 147           6.5          3.0           5.2          2.0       2
# 148           6.2          3.4           5.4          2.3       2
# 149           5.9          3.0           5.1          1.8       2
#
# [150 rows x 5 columns]

# %%
boston_data = pd.read_excel('data.xls',sheet_name='boston')
boston_data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# ..       ...     ...    ...
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %%
boston_data = pd.read_excel('data.xls',sheet_name='boston',header=0 \
                            ,usecols=['TAX','PTRATIO','B','LSTAT'])
boston_data
# Out:
#      TAX  PTRATIO       B  LSTAT
# 0    296     15.3  396.90   4.98
# 1    242     17.8  396.90   9.14
# 2    242     17.8  392.83   4.03
# 3    222     18.7  394.63   2.94
# 4    222     18.7  396.90   5.33
# ..   ...      ...     ...    ...
# 501  273     21.0  391.99   9.67
# 502  273     21.0  396.90   9.08
# 503  273     21.0  396.90   5.64
# 504  273     21.0  393.45   6.48
# 505  273     21.0  396.90   7.88
#
# [506 rows x 4 columns]

# %%
boston_data.to_excel('my_boston.xlsx',sheet_name='boston')

# %%
boston_data[:5]
# Out:
#    TAX  PTRATIO       B  LSTAT
# 0  296     15.3  396.90   4.98
# 1  242     17.8  396.90   9.14
# 2  242     17.8  392.83   4.03
# 3  222     18.7  394.63   2.94
# 4  222     18.7  396.90   5.33

# %%
import json

# %%
boston_data = pd.read_json('boston.json')
boston_data
# Out:
#      TAX  PTRATIO       B  LSTAT
# 0    296     15.3  396.90   4.98
# 1    242     17.8  396.90   9.14
# 2    242     17.8  392.83   4.03
# 3    222     18.7  394.63   2.94
# 4    222     18.7  396.90   5.33
# ..   ...      ...     ...    ...
# 501  273     21.0  391.99   9.67
# 502  273     21.0  396.90   9.08
# 503  273     21.0  396.90   5.64
# 504  273     21.0  393.45   6.48
# 505  273     21.0  396.90   7.88
#
# [506 rows x 4 columns]

# %%
boston_data.to_json('boston.json')

# %%
import sqlite3

# %%
boston_data = pd.read_excel('data.xls',sheet_name='boston',header=0 \
                            ,usecols=['TAX','PTRATIO','B','LSTAT'])
connection = sqlite3.connect('sql_db.sqlite')
boston_data.to_sql('boston', connection, if_exists='replace')
connection.commit()
connection.close()

# %%
connection = sqlite3.connect('sql_db.sqlite')
boston_data_sql = pd.io.sql.read_sql("select * from boston",connection)
connection.close()
boston_data_sql
# Out:
#      index  TAX  PTRATIO       B  LSTAT
# 0        0  296     15.3  396.90   4.98
# 1        1  242     17.8  396.90   9.14
# 2        2  242     17.8  392.83   4.03
# 3        3  222     18.7  394.63   2.94
# 4        4  222     18.7  396.90   5.33
# ..     ...  ...      ...     ...    ...
# 501    501  273     21.0  391.99   9.67
# 502    502  273     21.0  396.90   9.08
# 503    503  273     21.0  396.90   5.64
# 504    504  273     21.0  393.45   6.48
# 505    505  273     21.0  396.90   7.88
#
# [506 rows x 5 columns]

# %%
boston_data_sql
# Out:
#      index  TAX  PTRATIO       B  LSTAT
# 0        0  296     15.3  396.90   4.98
# 1        1  242     17.8  396.90   9.14
# 2        2  242     17.8  392.83   4.03
# 3        3  222     18.7  394.63   2.94
# 4        4  222     18.7  396.90   5.33
# ..     ...  ...      ...     ...    ...
# 501    501  273     21.0  391.99   9.67
# 502    502  273     21.0  396.90   9.08
# 503    503  273     21.0  396.90   5.64
# 504    504  273     21.0  393.45   6.48
# 505    505  273     21.0  396.90   7.88
#
# [506 rows x 5 columns]
