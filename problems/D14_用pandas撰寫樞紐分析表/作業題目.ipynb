# %% [markdown]
# 作業目標:<br>
# 1. 熟悉索引與欄位設定
# 2. 使用樞紐建立新資料

# %% [markdown]
# 作業重點:<br>
# 1. 多維度索引、欄位是有順序性的須注意
# 2. 使用樞紐建立資料需要注意參數<br>
#   index : 新資料的索引名稱<br>
#   columns : 新資料的欄位名稱<br>
#   values :新資料的值名稱

# %% [markdown]
# 題目: 運用下列分數資料重新建構資料，將索引(index)依序改為sex、class、student_id，欄位依序改成chinese_score、english_score、math_score<br><br>
# score_df = pd.DataFrame([[1,50,80,70,'boy',1],[2,60,45,50,'boy',2],[3,98,43,55,'boy',1],[4,70,69,89,'boy',2],[5,56,79,60,'girl',1],[6,60,68,55,'girl',2],[7,45,70,77,'girl',1],[8,55,77,76,'girl',2],[9,25,57,60,'girl',1],[10,88,40,43,'girl',3],[11,25,60,45,'boy',3],[12,80,60,23,'boy',3],[13,20,90,66,'girl',3],[14,50,50,50,'girl',3],[15,89,67,77,'girl',3]],columns=['student_id','math_score','english_score','chinese_score','sex','class'])

# %%
import pandas as pd
import numpy as np
score_df = pd.DataFrame([[1,50,80,70,'boy',1],[2,60,45,50,'boy',2],[3,98,43,55,'boy',1],[4,70,69,89,'boy',2],[5,56,79,60,'girl',1],[6,60,68,55,'girl',2],[7,45,70,77,'girl',1],[8,55,77,76,'girl',2],[9,25,57,60,'girl',1],[10,88,40,43,'girl',3],[11,25,60,45,'boy',3],[12,80,60,23,'boy',3],[13,20,90,66,'girl',3],[14,50,50,50,'girl',3],[15,89,67,77,'girl',3]],columns=['student_id','math_score','english_score','chinese_score','sex','class'])

# %%
score_df
# Out:
#     student_id  math_score  english_score  chinese_score   sex  class
# 0            1          50             80             70   boy      1
# 1            2          60             45             50   boy      2
# 2            3          98             43             55   boy      1
# 3            4          70             69             89   boy      2
# 4            5          56             79             60  girl      1
# 5            6          60             68             55  girl      2
# 6            7          45             70             77  girl      1
# 7            8          55             77             76  girl      2
# 8            9          25             57             60  girl      1
# 9           10          88             40             43  girl      3
# 10          11          25             60             45   boy      3
# 11          12          80             60             23   boy      3
# ...

# %%
pd.DataFrame(score_df[['english_score', 'math_score']], index = index)
# Out:
#                        english_score  math_score
# sex  class student_id
# boy  1     1                     NaN         NaN
#            3                     NaN         NaN
#      2     2                     NaN         NaN
#            4                     NaN         NaN
#      3     11                    NaN         NaN
#            12                    NaN         NaN
# girl 1     5                     NaN         NaN
#            7                     NaN         NaN
#            9                     NaN         NaN
#      2     6                     NaN         NaN
#            8                     NaN         NaN
#      3     10                    NaN         NaN
#            13                    NaN         NaN
#            14                    NaN         NaN
#            15                    NaN         NaN

# %%
#將索引(index)依序改為sex、class、student_id，欄位依序改成chinese_score、english_score、math_score

score_df = score_df.sort_values(by = ['sex', 'class', 'student_id'])
index = pd.MultiIndex.from_frame(pd.DataFrame(score_df, columns = ['sex', 'class', 'student_id']))
pd.DataFrame({'chinese_score': np.array(score_df['chinese_score']), 'english_score': np.array(score_df['english_score']), 'math_score': np.array(score_df['math_score'])}, index = index)
# Out:
#                        chinese_score  english_score  math_score
# sex  class student_id
# boy  1     1                      70             80          50
#            3                      55             43          98
#      2     2                      50             45          60
#            4                      89             69          70
#      3     11                     45             60          25
#            12                     23             60          80
# girl 1     5                      60             79          56
#            7                      77             70          45
#            9                      60             57          25
#      2     6                      55             68          60
#            8                      76             77          55
#      3     10                     43             40          88
#            13                     66             90          20
# ...

# %%
df = score_df.melt(id_vars = ['sex', 'class', 'student_id'])
df
# Out:
#      sex  class  student_id       variable  value
# 0    boy      1           1     math_score     50
# 1    boy      2           2     math_score     60
# 2    boy      1           3     math_score     98
# 3    boy      2           4     math_score     70
# 4   girl      1           5     math_score     56
# 5   girl      2           6     math_score     60
# 6   girl      1           7     math_score     45
# 7   girl      2           8     math_score     55
# 8   girl      1           9     math_score     25
# 9   girl      3          10     math_score     88
# 10   boy      3          11     math_score     25
# 11   boy      3          12     math_score     80
# 12  girl      3          13     math_score     20
# 13  girl      3          14     math_score     50
# 14  girl      3          15     math_score     89
# 15   boy      1           1  english_score     80
# 16   boy      2           2  english_score     45
# 17   boy      1           3  english_score     43
# ...

# %%
df['variable']
# Out:
# 0        math_score
# 1        math_score
# 2        math_score
# 3        math_score
# 4        math_score
# 5        math_score
# 6        math_score
# 7        math_score
# 8        math_score
# 9        math_score
# 10       math_score
# 11       math_score
# 12       math_score
# 13       math_score
# 14       math_score
# 15    english_score
# 16    english_score
# 17    english_score
# 18    english_score
# 19    english_score
# 20    english_score
# 21    english_score
# 22    english_score
# 23    english_score
# 24    english_score
# 25    english_score
# 26    english_score
# 27    english_score
# 28    english_score
# 29    english_score
# 30    chinese_score
# 31    chinese_score
# 32    chinese_score
# 33    chinese_score
# 34    chinese_score
# 35    chinese_score
# 36    chinese_score
# 37    chinese_score
# 38    chinese_score
# 39    chinese_score
# 40    chinese_score
# 41    chinese_score
# 42    chinese_score
# 43    chinese_score
# 44    chinese_score
# ...

# %%
df = score_df.melt(id_vars = ['sex', 'class', 'student_id'])
df.pivot(index = ['sex', 'class', 'student_id'], columns = [], values = ['chinese_score', 'english_score', 'math_score'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-32a32e8e301c> in <module>
#       1 df = score_df.melt(id_vars = ['sex', 'class', 'student_id'])
# ----> 2 df.pivot(index = ['sex', 'class', 'student_id'], columns = [], values = ['chinese_score', 'english_score', 'math_score'])
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    6874         from pandas.core.reshape.pivot import pivot
#    6875
# -> 6876         return pivot(self, index=index, columns=columns, values=values)
#    6877
#    6878     _shared_docs[
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/pivot.py in pivot(data, index, columns, values)
#     455             values = cast(Sequence[Label], values)
#     456             indexed = data._constructor(
# --> 457                 data[values]._values, index=index, columns=values
# ...
