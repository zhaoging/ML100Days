# %% [markdown]
# 範例目標:<br>
# 1. 實做繪製圖表
# 2. 藉由圖表對資料有初步認識，並解釋圖表意義

# %% [markdown]
# 範例重點:<br>
# 1. 每一種圖表都有相對應用的情境，分辨情境並繪製對應圖表
# 2. 圖像化展現，方便對於資料有初步的理解

# %%
import pandas as pd
import numpy as np

# %%
#單一折線圖
ts = pd.Series(np.random.randn(200), index=pd.date_range('1/1/2020', periods=200))
ts = ts.cumsum()
print(ts)
ts.plot()
# Out:
# 2020-01-01   -0.608545
# 2020-01-02    0.747394
# 2020-01-03    2.212776
# 2020-01-04    1.391381
# 2020-01-05    1.458669
#                 ...
# 2020-07-14    1.298053
# 2020-07-15    3.502392
# 2020-07-16    1.891398
# 2020-07-17    1.518606
# 2020-07-18    1.665975
# Freq: D, Length: 200, dtype: float64
# <AxesSubplot:>

# %%
#多個折線圖同時畫出
df = pd.DataFrame(np.random.randn(200, 3), index=pd.date_range('1/1/2020', periods=200), columns=["A","B","C"])
df = df.cumsum()
print(df)
df.plot();
# Out:
#                     A         B          C
# 2020-01-01   0.741629 -0.607324   0.561956
# 2020-01-02   0.793874  0.168951   0.419147
# 2020-01-03   0.710208  0.120668  -0.341290
# 2020-01-04   0.336902 -0.174375   0.773143
# 2020-01-05  -1.343445  1.439251   0.254359
# ...               ...       ...        ...
# 2020-07-14 -12.939418  9.001658  26.768571
# 2020-07-15 -13.889219  8.880540  27.143394
# 2020-07-16 -12.985844  8.686636  25.696722
# 2020-07-17 -13.423293  8.263714  26.614351
# 2020-07-18 -13.636601  7.616168  26.592277
#
# [200 rows x 3 columns]

# %%
#圓餅圖
df = pd.Series(np.random.rand(4), index=["A","B","C","D"],name="title")
print(df)
df.plot.pie()
# Out:
# A    0.580490
# B    0.421980
# C    0.055521
# D    0.875018
# Name: title, dtype: float64
# <AxesSubplot:ylabel='title'>

# %%
#長條圖
df = pd.DataFrame(np.random.rand(10, 2), columns=["A","B"])
print(df)
df.plot.bar();
# Out:
#           A         B
# 0  0.839170  0.705202
# 1  0.142056  0.941674
# 2  0.152223  0.823674
# 3  0.298278  0.641946
# 4  0.794395  0.909165
# 5  0.843647  0.133385
# 6  0.528783  0.416496
# 7  0.207547  0.558013
# 8  0.274259  0.776475
# 9  0.449347  0.858696

# %%
df.plot.bar(stacked=True);

# %%
#箱型圖
df = pd.DataFrame(np.random.rand(10, 2), columns=["A","B"])
print(df)
df.boxplot()
# Out:
#           A         B
# 0  0.409238  0.027752
# 1  0.573973  0.405637
# 2  0.071235  0.913183
# 3  0.707490  0.292884
# 4  0.976064  0.282910
# 5  0.169591  0.250542
# 6  0.271032  0.628103
# 7  0.204834  0.530809
# 8  0.920946  0.197982
# 9  0.120615  0.036727
# <AxesSubplot:>

# %%
#散佈圖
df = pd.DataFrame(np.random.rand(10, 2), columns=["A","B"])
print(df)
df.plot.scatter(x='A', y='B')
# Out:
#           A         B
# 0  0.314404  0.217213
# 1  0.300593  0.749019
# 2  0.989338  0.138211
# 3  0.324061  0.055189
# 4  0.186194  0.337538
# 5  0.185660  0.526666
# 6  0.961584  0.432220
# 7  0.806463  0.212020
# 8  0.154007  0.953002
# 9  0.384693  0.771217
# <AxesSubplot:xlabel='A', ylabel='B'>
